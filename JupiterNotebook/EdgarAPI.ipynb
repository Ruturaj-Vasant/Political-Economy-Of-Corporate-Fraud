# %%
from edgar import *
set_identity('ruturaj@gmail.com')
import pandas as pd

# %%
apple = Company('AAPL')
apple
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭────────────────────────────────────────────── 🏢 Apple Inc. AAPL ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │                                                                                                                 │
# │ ╭───────────────────────────────────────────────── 📋 Entity ─────────────────────────────────────────────────╮ │
# │ │                                                                                                             │ │
# │ │   CIK   320193   Type   Operating   ○                                                                       │ │
# │ │                                                                                                             │ │
# ...

# %%
apple.get_financials()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────────── XBRL Document ─────────────────────────────────────────────────╮
# │            Entity Information                                                                                   │
# │                                                                                                                 │
# │   Property                   Value                                                                              │
# │  ───────────────────────────────────────                                                                        │
# │   entity_name                Apple Inc.                                                                         │
# │   ticker                     AAPL                                                                               │
# ...

# %%
apple.get_filings()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────── Filings for Apple Inc. [320193] ────────────────────────────────────────╮
# │                                                                                                                 │
# │                                                                              Filing                             │
# │    Form        Description                                                   Date         Accession Number      │
# │  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────  │
# │    8-K         Current report                                                2025-07-09   0001140361-25-0252…   │
# │    25-NSE      Notice of matured/redeemed/retired securities by exchanges    2025-05-22   0001354457-25-0004…   │
# ...

# %%
apple.cik
apple.name
filings = apple.get_filings(form='DEF 14A')[-1]
print({filings.report_date})
print(pretty(filings.view()))
# Out:
# {'1995-01-24'}
# <PAGE>   1
#
#           PROXY STATEMENT PURSUANT TO SECTION 14(A) OF THE SECURITIES
#                   EXCHANGE ACT OF 1934 (AMENDMENT NO.       )
#
# Filed by the Registrant  / /
# Filed by a Party other than the Registrant  /X/
#
# Check the appropriate box:
#
# / /  Preliminary Proxy Statement
# /X/  Definitive Proxy Statement
# / /  Definitive Additional Materials
# / /  Soliciting Material Pursuant to sec. 240.14a-11(c) or sec. 240.14a-12
#
#                               APPLE COMPUTER, INC.
#                 (Name of Registrant as Specified in its Charter)
#
#                               APPLE COMPUTER, INC.
#                    (Name of Person(s) Filing Proxy Statement)
#
# Payment of Filing Fee (Check the appropriate box):
#
# /X/  $125 per Exchange Act Rules 0-11(c)(1)(ii), 14a-6(i)(1), or 14a-6(j)(2).
# / /  $500 per each party to the controversy pursuant to Exchange Act Rule
#      14a-6(i)(3).
# ...
